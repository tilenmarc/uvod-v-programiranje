# %% [markdown]
# # Analiza podatkov
#
# V tem dokumentu bomo analizirali podatke o knjiga

# %%
import pandas as pd

knjige = pd.read_csv("knjige.csv", index_col="id")

# %%
knjige.head(5)
# Out:
#                                                      naslov  id_avtorja  \
# id
# 2767052             The Hunger Games (The Hunger Games, #1)    153394.0
# 1885                                    Pride and Prejudice      1265.0
# 2657                                  To Kill a Mockingbird      1825.0
# 58613451  Harry Potter and the Order of the Phoenix (Har...   1077326.0
# 19063                                        The Book Thief     11466.0
#
#           povprecna_ocena  stevilo_ocen  stevilo_recenzij  stevilo_strani  \
# id
# 2767052              4.35      10080244            268807           374.0
# 1885                 4.30       4900979            153011           279.0
# 2657                 4.26       6993055            135628           323.0
# 58613451             4.50       3856441             80331           896.0
# 19063                4.39       2925868            163395           592.0
#
#             jezik  leto_izdaje  trenutno_bere  \
# id
# ...

# %%
knjige.tail(5)
# Out:
#                                                       naslov  id_avtorja  \
# id
# 157981682                                   The Book of Love     24902.0
# 3109       The Omnivore's Dilemma: A Natural History of F...      2121.0
# 264                                   The Portrait of a Lady       159.0
# 18521                                    A Room of One’s Own      6765.0
# 38374795                                         Howards End     86404.0
#
#            povprecna_ocena  stevilo_ocen  stevilo_recenzij  stevilo_strani  \
# id
# 157981682             3.50         11400              2452           628.0
# 3109                  4.19        211330             14727           450.0
# 264                   3.80         85922              4573           797.0
# 18521                 4.22        270127             26348           112.0
# 38374795              3.96         95726              5081           318.0
#
#              jezik  leto_izdaje  trenutno_bere  \
# id
# ...

# %%
knjige[["naslov", "povprecna_ocena"]]
# Out:
#                                                       naslov  povprecna_ocena
# id
# 2767052              The Hunger Games (The Hunger Games, #1)             4.35
# 1885                                     Pride and Prejudice             4.30
# 2657                                   To Kill a Mockingbird             4.26
# 58613451   Harry Potter and the Order of the Phoenix (Har...             4.50
# 19063                                         The Book Thief             4.39
# ...                                                      ...              ...
# 157981682                                   The Book of Love             3.50
# 3109       The Omnivore's Dilemma: A Natural History of F...             4.19
# 264                                   The Portrait of a Lady             3.80
# 18521                                    A Room of One’s Own             4.22
# 38374795                                         Howards End             3.96
#
# [1000 rows x 2 columns]

# %%
knjige["povprecna_ocena"] + knjige["stevilo_recenzij"]
# Out:
# id
# 2767052      268811.35
# 1885         153015.30
# 2657         135632.26
# 58613451      80335.50
# 19063        163399.39
#                ...
# 157981682      2455.50
# 3109          14731.19
# 264            4576.80
# 18521         26352.22
# 38374795       5084.96
# Length: 1000, dtype: float64

# %%
knjige["leto_izdaje"] = knjige["leto_izdaje"].astype("Int64")

# %%
knjige["desetletje"] = (knjige["leto_izdaje"] // 10) * 10

# %%
najboljse_leto = knjige[knjige["leto_izdaje"] == 2006]

# %%
najboljse_leto.sort_values("povprecna_ocena", ascending=False).head(10)
# Out:
#                                                      naslov  id_avtorja  \
# id
# 68428             Mistborn: The Final Empire (Mistborn, #1)     38550.0
# 42900         Lover Awakened (Black Dagger Brotherhood, #3)     20248.0
# 19063                                        The Book Thief     11466.0
# 1617                                                  Night      1049.0
# 4069                               Man's Search for Meaning      2782.0
# 166997                                               Stoner     51229.0
# 7445                                       The Glass Castle      3275.0
# 228086938  Banker's Holiday: A Novel of Fiscal Irregularity    808471.0
# 35729          Lover Eternal (Black Dagger Brotherhood, #2)     20248.0
# 14891                              A Tree Grows in Brooklyn   2327917.0
#
#            povprecna_ocena  stevilo_ocen  stevilo_recenzij  stevilo_strani  \
# id
# 68428                 4.49       1024372             86091           541.0
# ...

# %%
knjige.groupby("desetletje").size()
# Out:
# desetletje
# 1970     13
# 1980     36
# 1990    144
# 2000    467
# 2010    243
# 2020     88
# dtype: int64

# %%
ocena_po_desetletjih = knjige.groupby("desetletje")["povprecna_ocena"].mean()

# %%
ocena_po_desetletjih.plot.line()
# Out:
# <Axes: xlabel='desetletje'>

# %%
ax = ocena_po_desetletjih.plot.bar(
    figsize=(10, 5),
    color="pink",
    edgecolor="black",
    width=0.75
)
ax.set_title("Povprecna ocena knjig po desetletjih")
ax.set_xlabel("desetletje")
ax.set_ylabel("povprecna ocena")
ax.grid(axis="y", linestyle="--", alpha=0.4)
ax.set_axisbelow(True)
ax.tick_params(axis="x", rotation=0)

# %%
knjige.plot.scatter(x="leto_izdaje", y="povprecna_ocena")
# Out:
# <Axes: xlabel='leto_izdaje', ylabel='povprecna_ocena'>

# %%
knjige[knjige["stevilo_strani"] < 400].plot.scatter(x="stevilo_strani", y="povprecna_ocena")
# Out:
# <Axes: xlabel='stevilo_strani', ylabel='povprecna_ocena'>

# %%
knjige["strani10"] = knjige["stevilo_strani"] // 10 * 10
knjige10 = knjige[knjige["stevilo_strani"] < 1000].groupby("strani10")["povprecna_ocena"].mean()
knjige10.plot.line()
# Out:
# <Axes: xlabel='strani10'>

# %%
avtorji = pd.read_csv("avtorji.csv")

# %%
knjige_avtorji = pd.merge(knjige, avtorji, left_on="id_avtorja", right_on="id")

# %%
naj_avtorji = knjige_avtorji.groupby("ime").size().sort_values(ascending=False).head(10)

# %%
naj_avtorji.plot.bar()
# Out:
# <Axes: xlabel='ime'>

# %%
zanri = pd.read_csv("zanri.csv")
knjige_zanri_avtorji = pd.merge(pd.merge(knjige, zanri, left_on="id", right_on="id_knjige"), avtorji, left_on="id_avtorja", right_on="id")
knjige_zanri_avtorji
# Out:
#                                        naslov  id_avtorja  povprecna_ocena  \
# 0     The Hunger Games (The Hunger Games, #1)    153394.0             4.35
# 1     The Hunger Games (The Hunger Games, #1)    153394.0             4.35
# 2     The Hunger Games (The Hunger Games, #1)    153394.0             4.35
# 3     The Hunger Games (The Hunger Games, #1)    153394.0             4.35
# 4     The Hunger Games (The Hunger Games, #1)    153394.0             4.35
# ...                                       ...         ...              ...
# 9966                              Howards End     86404.0             3.96
# 9967                              Howards End     86404.0             3.96
# 9968                              Howards End     86404.0             3.96
# 9969                              Howards End     86404.0             3.96
# 9970                              Howards End     86404.0             3.96
#
# ...

# %%
naj_avtorji_classics = knjige_zanri_avtorji[knjige_zanri_avtorji["zanr"] == "Classics"].groupby("ime").size().sort_values(ascending=False).head(10)

# %%
naj_avtorji_classics
# Out:
# ime
# William Shakespeare    11
# J.K. Rowling           11
# C.S. Lewis              9
# J.R.R. Tolkien          8
# Jane Austen             7
# Stephen King            7
# Charles Dickens         6
# Dr. Seuss               6
# Roald Dahl              5
# Ray Bradbury            5
# dtype: int64
