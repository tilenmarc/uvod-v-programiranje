# %% [markdown]
# # Analiza podatkov

# %%
import pandas as pd

filmi = pd.read_csv("filmi.csv", index_col="id")

# %%
filmi.head(10)
# Out:
#                           naslov  ocena  cas  leto     oznaka  \
# id
# 43014           Sunset Boulevard    8.4  110  1950   Approved
# 42192                  Vse o Evi    8.2  138  1950   Approved
# 42876                    V gozdu    8.2   88  1950  Not Rated
# 42546                     Harvey    7.9  104  1950   Approved
# 42646  King Solomon&#x27;s Mines    6.7  103  1950   Approved
# 42276             Born Yesterday    7.5  103  1950   Approved
# 42367         Cyrano de Bergerac    7.4  113  1950   Approved
# 42832       Panic in the Streets    7.2   96  1950   Approved
# 42200         Annie Get Your Gun    6.9  107  1950   Approved
# 42393           Destination Moon    6.3   92  1950   Approved
#
#                                                     opis       cena  \
# id
# 43014  A screenwriter develops a dangerous relationsh...  1752000.0
# 42192  A seemingly timid but secretly ruthless ingénu...  1400000.0
# ...

# %%
filmi.tail(10)
# Out:
#                     naslov  ocena  cas  leto     oznaka  \
# id
# 28607951             Anora    7.5  139  2024          R
# 17526714     The Substance    7.3  141  2024          R
# 1262426     Wicked: Part I    7.5  160  2024         PG
# 8999762      The Brutalist    7.4  216  2024          R
# 21823606       A Real Pain    7.1   90  2024          R
# 15239678    Dune: Part Two    8.5  166  2024      PG-13
# 4772188            Straume    7.9   85  2024         PG
# 14961016  Ainda Estou Aqui    8.3  137  2024      PG-13
# 20221436      Emilia Pérez    5.4  132  2024          R
# 30953759     No Other Land    8.3   92  2024  Not Rated
#
#                                                        opis         cena  \
# id
# 28607951  A young stripper from Brooklyn meets and impul...    6000000.0
# 17526714  A fading celebrity takes a black-market drug: ...   17500000.0
# 1262426   Elphaba, a young woman ridiculed for her green...  150000000.0
# ...

# %%
filmi[["naslov", "leto"]]
# Out:
#                              naslov  leto
# id
# 43014              Sunset Boulevard  1950
# 42192                     Vse o Evi  1950
# 42876                       V gozdu  1950
# 42546                        Harvey  1950
# 42646     King Solomon&#x27;s Mines  1950
# ...                             ...   ...
# 15239678             Dune: Part Two  2024
# 4772188                     Straume  2024
# 14961016           Ainda Estou Aqui  2024
# 20221436               Emilia Pérez  2024
# 30953759              No Other Land  2024
#
# [1075 rows x 2 columns]

# %%
filmi["leto"] + 1000
# Out:
# id
# 43014       2950
# 42192       2950
# 42876       2950
# 42546       2950
# 42646       2950
#             ...
# 15239678    3024
# 4772188     3024
# 14961016    3024
# 20221436    3024
# 30953759    3024
# Name: leto, Length: 1075, dtype: int64

# %%
filmi[filmi["leto"] == 2005]
# Out:
#                                                    naslov  ocena  cas  leto  \
# id
# 388795                                     Gora Brokeback    7.7  134  2005
# 363771         Zgodbe iz Narnije: Lev, carovnica in omara    6.9  143  2005
# 360717                                          King Kong    7.2  187  2005
# 397535                                      Spomini gejse    7.3  145  2005
# 358273                                       Hoja po robu    7.8  136  2005
# 387131                                      Zvesti vrtnar    7.3  129  2005
# 312004          Wallace in Gromit: Prekletstvo Strahouhca    7.5   85  2005
# 379725                                             Capote    7.3  114  2005
# 365737                                            Syriana    6.9  128  2005
# 410097                                         Gor in dol    7.3  116  2005
# 428803                       La marche de l&#x27;empereur    7.5   80  2005
# ...

# %%
zasluzkarji = filmi[filmi["zasluzek"] > 10**9]
zasluzkarji
# Out:
#                                       naslov  ocena  cas  leto oznaka  \
# id
# 107290                           Jurski park    8.2  127  1993  PG-13
# 120338                               Titanik    7.9  194  1997  PG-13
# 167260   Gospodar prstanov: Kraljeva vrnitev    9.0  201  2003  PG-13
# 383574   Pirati s Karibov: Mrtveceva skrinja    7.4  151  2006  PG-13
# 468569                            Vitez teme    9.0  152  2008  PG-13
# 499549                                Avatar    7.9  162  2009  PG-13
# 1014759       Alice se vrne v čudežno deželo    6.4  108  2010     PG
# 435761                          Svet igrač 3    8.3  103  2010      G
# 1074638                              Skyfall    7.8  143  2012  PG-13
# 2294629                    Ledeno kraljestvo    7.4  102  2013     PG
# 2948356                          Zootropolis    8.0  108  2016     PG
# 1825683                        Black Panther    7.3  134  2018  PG-13
# ...

# %%
filmi["profit"] = filmi["zasluzek"] - filmi["cena"]

# %%
filmi
# Out:
#                              naslov  ocena  cas  leto     oznaka  \
# id
# 43014              Sunset Boulevard    8.4  110  1950   Approved
# 42192                     Vse o Evi    8.2  138  1950   Approved
# 42876                       V gozdu    8.2   88  1950  Not Rated
# 42546                        Harvey    7.9  104  1950   Approved
# 42646     King Solomon&#x27;s Mines    6.7  103  1950   Approved
# ...                             ...    ...  ...   ...        ...
# 15239678             Dune: Part Two    8.5  166  2024      PG-13
# 4772188                     Straume    7.9   85  2024         PG
# 14961016           Ainda Estou Aqui    8.3  137  2024      PG-13
# 20221436               Emilia Pérez    5.4  132  2024          R
# 30953759              No Other Land    8.3   92  2024  Not Rated
#
#                                                        opis         cena  \
# id
# 43014     A screenwriter develops a dangerous relationsh...    1752000.0
# ...

# %%
filmi.sort_values("profit", ascending=False)
# Out:
#                         naslov  ocena  cas  leto     oznaka  \
# id
# 499549                  Avatar    7.9  162  2009      PG-13
# 120338                 Titanik    7.9  194  1997      PG-13
# 1630029       Avatar: Pot vode    7.5  192  2022      PG-13
# 1517268                 Barbie    6.8  114  2023      PG-13
# 1745960      Top Gun: Maverick    8.2  130  2022      PG-13
# ...                        ...    ...  ...   ...        ...
# 29795707          War Is Over!    6.3   11  2023        NaN
# 29118186  The Last Repair Shop    7.4   39  2023      TV-PG
# 21823606           A Real Pain    7.1   90  2024          R
# 14961016      Ainda Estou Aqui    8.3  137  2024      PG-13
# 30953759         No Other Land    8.3   92  2024  Not Rated
#
#                                                        opis         cena  \
# id
# 499549    A paraplegic Marine dispatched to the moon Pan...  237000000.0
# 120338    A seventeen-year-old aristocrat falls in love ...  200000000.0
# ...

# %%
filmi[filmi["profit"].notna()].sort_values("profit", ascending=True).head(10)
# Out:
#                                        naslov  ocena  cas  leto oznaka  \
# id
# 118799                      Življenje je lepo    8.6  116  1997  PG-13
# 8178634                RRR (Rise Roar Revolt)    7.8  187  2022  TV-MA
# 99334                      Cyrano de Bergerac    7.5  137  1990     PG
# 110428             The Madness of King George    7.2  110  1994  PG-13
# 1488589   Guillermo del Toro&#x27;s Pinocchio    7.6  117  2022     PG
# 10293406                 The Power of the Dog    6.8  126  2021      R
# 120889                 Zivljenje po zivljenju    7.0  113  1998  PG-13
# 64418                           Hello, Dolly!    7.0  146  1969      G
# 3581652               Zgodbe z zahodne strani    7.1  156  2021  PG-13
# 185014                           Zlati fantje    7.2  107  2000      R
#
#                                                        opis          cena  \
# id
# 118799    When an open-minded Jewish waiter and his son ...  1.500000e+10
# ...

# %%
filmi["desetletje"] = (filmi["leto"] // 10) * 10

# %%
filmi.groupby("desetletje").count()["naslov"]
# Out:
# desetletje
# 1950    152
# 1960    148
# 1970    134
# 1980    136
# 1990    137
# 2000    146
# 2010    151
# 2020     71
# Name: naslov, dtype: int64

# %%
filmi.groupby("desetletje")["ocena"].mean()
# Out:
# desetletje
# 1950    7.052632
# 1960    7.213514
# 1970    7.240299
# 1980    7.272059
# 1990    7.474453
# 2000    7.577397
# 2010    7.656291
# 2020    7.422535
# Name: ocena, dtype: float64

# %%
najvecji_zasluzkarji = filmi.sort_values("profit", ascending=False).head(15)
najvecji_zasluzkarji
# Out:
#                                        naslov  ocena  cas  leto oznaka  \
# id
# 499549                                 Avatar    7.9  162  2009  PG-13
# 120338                                Titanik    7.9  194  1997  PG-13
# 1630029                      Avatar: Pot vode    7.5  192  2022  PG-13
# 1517268                                Barbie    6.8  114  2023  PG-13
# 1745960                     Top Gun: Maverick    8.2  130  2022  PG-13
# 2294629                     Ledeno kraljestvo    7.4  102  2013     PG
# 1825683                         Black Panther    7.3  134  2018  PG-13
# 167260    Gospodar prstanov: Kraljeva vrnitev    9.0  201  2003  PG-13
# 107290                            Jurski park    8.2  127  1993  PG-13
# 7286456                                 Joker    8.3  122  2019      R
# 110357                          The Lion King    8.5   88  1994      G
# 1074638                               Skyfall    7.8  143  2012  PG-13
# ...

# %%
najvecji_zasluzkarji.plot.bar(x="naslov", y="profit", title="filmi z najvecjim zasluzkom")
# Out:
# <Axes: title={'center': 'filmi z najvecjim zasluzkom'}, xlabel='naslov'>

# %%
filmi[["leto", "ocena"]].plot.scatter(x="leto", y="ocena")
# Out:
# <Axes: xlabel='leto', ylabel='ocena'>

# %%
filmi.groupby("desetletje")["ocena"].mean().plot.bar()
# Out:
# <Axes: xlabel='desetletje'>

# %%
filmi.plot.scatter(x="cas", y="ocena")
# Out:
# <Axes: xlabel='cas', ylabel='ocena'>

# %%
filmi["cas_10"] = (filmi["cas"] // 10) * 10
filmi.groupby("cas_10")["ocena"].mean().plot.bar()
# Out:
# <Axes: xlabel='cas_10'>

# %%
filmi.groupby("ocena")["naslov"].count().plot.pie(ylabel="delez filmov z oceno")
# Out:
# <Axes: ylabel='delez filmov z oceno'>

# %%
zanri = pd.read_csv("filmi_zanri.csv")

# %%
filmi_z_zanri = pd.merge(filmi, zanri, left_on="id", right_on="id_filma")
filmi_z_zanri
# Out:
#                 naslov  ocena  cas  leto     oznaka  \
# 0     Sunset Boulevard    8.4  110  1950   Approved
# 1     Sunset Boulevard    8.4  110  1950   Approved
# 2     Sunset Boulevard    8.4  110  1950   Approved
# 3     Sunset Boulevard    8.4  110  1950   Approved
# 4     Sunset Boulevard    8.4  110  1950   Approved
# ...                ...    ...  ...   ...        ...
# 4912      Emilia Pérez    5.4  132  2024          R
# 4913      Emilia Pérez    5.4  132  2024          R
# 4914      Emilia Pérez    5.4  132  2024          R
# 4915     No Other Land    8.3   92  2024  Not Rated
# 4916     No Other Land    8.3   92  2024  Not Rated
#
#                                                    opis        cena  \
# 0     A screenwriter develops a dangerous relationsh...   1752000.0
# 1     A screenwriter develops a dangerous relationsh...   1752000.0
# 2     A screenwriter develops a dangerous relationsh...   1752000.0
# ...

# %%
filmi_z_zanri[(filmi_z_zanri["zanr"] == "Comedy") | (filmi_z_zanri["zanr"] == "Dark Comedy")]
# Out:
#                     naslov  ocena  cas  leto    oznaka  \
# 0         Sunset Boulevard    8.4  110  1950  Approved
# 13                  Harvey    7.9  104  1950  Approved
# 26          Born Yesterday    7.5  103  1950  Approved
# 38      Annie Get Your Gun    6.9  107  1950  Approved
# 51    Gerald McBoing-Boing    7.1    8  1950  Approved
# ...                    ...    ...  ...   ...       ...
# 4843     Ik ben geen robot    7.1   23  2023       NaN
# 4864                 Anora    7.5  139  2024         R
# 4867                 Anora    7.5  139  2024         R
# 4871         The Substance    7.3  141  2024         R
# 4886           A Real Pain    7.1   90  2024         R
#
#                                                    opis        cena  \
# 0     A screenwriter develops a dangerous relationsh...   1752000.0
# 13    A whimsical man is thought to be insane due to...         NaN
# 26    While in Washington to lobby for favorable leg...         NaN
# ...

# %%
komedije = filmi_z_zanri[(filmi_z_zanri["zanr"] == "Horror")] 
romance = filmi_z_zanri[(filmi_z_zanri["zanr"] == "Romance")][["id_filma", "zanr"]]
romanticne_komedije = pd.merge(komedije, romance, left_on="id_filma", right_on="id_filma")
romanticne_komedije
# Out:
#     naslov  ocena  cas  leto oznaka  \
# 0  Drakula    7.4  128  1992      R
#
#                                                 opis        cena     zasluzek  \
# 0  The centuries old vampire Count Dracula comes ...  40000000.0  215862692.0
#
#         profit  desetletje  cas_10  id_filma  zanr_x   zanr_y
# 0  175862692.0        1990     120    103874  Horror  Romance

# %%
osebe = pd.read_csv("osebe.csv")
osebe_filmi = pd.read_csv("osebe_filmi.csv")

igralci_filmi = pd.merge(osebe, osebe_filmi[osebe_filmi["vloga"] == "I"], left_on="id", right_on="id_igralca")
igralci_filmi
# Out:
#             id                 ime  id_filma  id_igralca vloga
# 0           34      William Holden     43014          34     I
# 1           34      William Holden     42276          34     I
# 2           34      William Holden     46359          34     I
# 3           34      William Holden     47437          34     I
# 4           34      William Holden     46874          34     I
# ...        ...                 ...       ...         ...   ...
# 2970   1035423  Karla Sofía Gascón  20221436     1035423     I
# 2971   1411125        Selena Gomez  20221436     1411125     I
# 2972  15732721       Yuval Abraham  30953759    15732721     I
# 2973  15732719          Basel Adra  30953759    15732719     I
# 2974  15732720       Hamdan Ballal  30953759    15732720     I
#
# [2975 rows x 5 columns]

# %%
igralci_filmi.groupby("ime")["id_filma"].count().sort_values(ascending=False).head(10)
# Out:
# ime
# Paul Newman          12
# Richard Burton       12
# William Holden       11
# Ralph Fiennes        10
# Harrison Ford        10
# Elizabeth Taylor      9
# Jack Lemmon           9
# Winston Hibler        9
# Tom Hanks             9
# Leonardo DiCaprio     8
# Name: id_filma, dtype: int64

# %%
filmi_z_zanri.groupby("zanr")["cas"].mean()[filmi_z_zanri.groupby("zanr")["naslov"].count() > 50].sort_values().plot.bar()
# Out:
# <Axes: xlabel='zanr'>

# %%
igralci_igralci = pd.merge(igralci_filmi, igralci_filmi, left_on="id_filma", right_on="id_filma")[["ime_x", "ime_y"]]
igralci_igralci
# Out:
#                ime_x               ime_y
# 0     William Holden      William Holden
# 1     William Holden      Gloria Swanson
# 2     William Holden  Erich von Stroheim
# 3     William Holden      William Holden
# 4     William Holden       Judy Holliday
# ...              ...                 ...
# 8734      Basel Adra          Basel Adra
# 8735      Basel Adra       Hamdan Ballal
# 8736   Hamdan Ballal       Yuval Abraham
# 8737   Hamdan Ballal          Basel Adra
# 8738   Hamdan Ballal       Hamdan Ballal
#
# [8739 rows x 2 columns]

# %%
import networkx as nx

# %%
G = nx.from_pandas_edgelist(igralci_igralci, "ime_x", "ime_y")
G = nx.subgraph(G, list(nx.connected_components(G))[0])

# %%
sorted(list(nx.pagerank(G).items()), key=lambda x: -x[1])
# Out:
# [('William Holden', 0.0039248935152943025),
#  ('Paul Newman', 0.0036857676036323407),
#  ('Ralph Fiennes', 0.0036697768227272544),
#  ('Harrison Ford', 0.0030984716950853966),
#  ('Jack Lemmon', 0.0030301490706666073),
#  ('Gregory Peck', 0.0030130759563620495),
#  ('Tom Hanks', 0.002997304444901192),
#  ('Matt Damon', 0.0029092102722897534),
#  ('Robert De Niro', 0.0028896155403104577),
#  ('Richard Burton', 0.0028542449121627665),
#  ('Meryl Streep', 0.0028536490627390984),
#  ('Sidney Poitier', 0.002853195882746507),
#  ('Leonardo DiCaprio', 0.0028375466807874063),
#  ('Elizabeth Taylor', 0.002759541435338531),
#  ('Daniel Day-Lewis', 0.0026105458839545377),
#  ('Jane Fonda', 0.0025989178591270027),
#  ('Jack Nicholson', 0.002587904905743125),
#  ('Geoffrey Rush', 0.0025505928775952447),
#  ('Marlon Brando', 0.0025380363399038664),
#  ('Johnny Depp', 0.002519084281653282),
#  ('Anthony Hopkins', 0.0024278714651975323),
#  ('John Wayne', 0.0024259829948590837),
# ...

# %%
nx.draw(G, node_size=1)
